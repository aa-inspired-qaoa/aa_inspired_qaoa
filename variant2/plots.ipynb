# %%
import os
import sys
import inspect
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import data_extraction as d
import matplotlib.pyplot as plt

# %% [markdown]
# ### Variant 2

# %%
plt.figure(figsize=(8, 6), dpi=80)

success_probs2, sat_probs2 = d.get_exp_results('results_n10p2/results_10.json')
success_probs4, sat_probs4 = d.get_exp_results('results_n10p4/results_10.json')
success_probs6, sat_probs6 = d.get_exp_results('results_n10p6/results_10.json')
success_probs8, sat_probs8 = d.get_exp_results('results_n10p8/results_10.json')
success_probs10, sat_probs10 = d.get_exp_results('results_n10p10/results_10.json')
fig = d.plot_dicts(success_probs2, success_probs4, success_probs6, success_probs8, success_probs10, labels=['p=2', 'p=4', 'p=6', 'p=8', 'p=10'], sat_probs=sat_probs2)
plt.show()

# %% [markdown]
# ### Variant 2 with threshold $T=0.10$

# %%
plt.figure(figsize=(10, 10), dpi=80)

th = 0.90
success_probs2, sat_probs2 = d.get_exp_results_th('results_n10p2/results_10.json', th)
success_probs4, sat_probs4 = d.get_exp_results_th('results_n10p4/results_10.json', th)
success_probs6, sat_probs6 = d.get_exp_results_th('results_n10p6/results_10.json', th)
success_probs8, sat_probs8 = d.get_exp_results_th('results_n10p8/results_10.json', th)
success_probs10, sat_probs10 = d.get_exp_results_th('results_n10p10/results_10.json', th)
fig = d.plot_dicts(success_probs2, success_probs4, success_probs6, success_probs8, success_probs10, labels=['p=2', 'p=4', 'p=6', 'p=8', 'p=10'], sat_probs=sat_probs2)
plt.show()

# %% [markdown]
# ### Variant 2 with threshold $T=0.25$

# %%
plt.figure(figsize=(8, 6), dpi=80)

th = 0.75
success_probs2, sat_probs2 = d.get_exp_results_th('results_n10p2/results_10.json', th)
success_probs4, sat_probs4 = d.get_exp_results_th('results_n10p4/results_10.json', th)
success_probs6, sat_probs6 = d.get_exp_results_th('results_n10p6/results_10.json', th)
success_probs8, sat_probs8 = d.get_exp_results_th('results_n10p8/results_10.json', th)
success_probs10, sat_probs10 = d.get_exp_results_th('results_n10p10/results_10.json', th)
fig = d.plot_dicts(success_probs2, success_probs4, success_probs6, success_probs8, success_probs10, labels=['p=2', 'p=4', 'p=6', 'p=8', 'p=10'], sat_probs=sat_probs2)
plt.show()
